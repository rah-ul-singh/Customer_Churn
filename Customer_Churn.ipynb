# %%
#importing required libraries
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
# Loading the data
bank_data = pd.read_csv("Artificial_Neural_Network_Case_Study_data.csv")

# %%
bank_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
bank_data=bank_data.drop(["RowNumber", "CustomerId", "Surname"], axis= 1)
bank_data
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
bank_data.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
X = bank_data.drop(["Exited"], axis= 1)
y= bank_data["Exited"]

print(X.columns)
print(y)
# X = bank_data.iloc[:,:-1].values
# print("Independent variables are:", X)
# #taking all rows but only the last column as Y(dependent variable)
# y = bank_data.iloc[:, -1].values
# print("Dependent variable is:", y)
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary'],
#       dtype='object')
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
# Transforming the gender variable, labels are chosen randomly
label_encoder = LabelEncoder()
X['geography_encoded'] = label_encoder.fit_transform(X['Geography'])
X['gender_encoded'] = label_encoder.fit_transform(X['Gender'])
X=X.drop(["Geography", "Gender"], axis = 1)
print(X)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  geography_encoded  gender_encoded
# 0                  1        101348.88                  0               0
# 1                  1        112542.58                  2               0
# 2                  0        113931.57                  0               0
# 3                  0         93826.63                  0               0
# 4                  1         79084.10                  2               0
# ...              ...              ...                ...             ...
# 9995               0         96270.64                  0               1
# 9996               1        101699.77                  0               1
# 9997               1         42085.58                  0               0
# 9998               0         92888.52                  1               1
# 9999               0         38190.78                  0               0
#
# [10000 rows x 10 columns]

# %%
bank_data
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
# # Transforming the geography column variable, labels are chosen randomly, the ct asks for argument [1] the index of the target vb
# ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(),[1])], remainder = 'passthrough')
# X = np.array(ct.fit_transform(X))
# print(X)

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
#printing the dimensions of each of those snapshots to see amount of rows and columns i each of them
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (8000, 10) (2000, 10)
# (8000,) (2000,)

# %%
# Data Scaling/normalization of the features that will go to the NN
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#----------------------- Building the model -----------------------#

# Initializing the ANN by calling the Sequential class fromm keras of Tensorflow
ann = tf.keras.models.Sequential()

#----------------------------------------------------------------------------------
# Adding "fully connected" INPUT layer to the Sequential ANN by calling Dense class
#----------------------------------------------------------------------------------
# Number of Units = 6 and Activation Function = Rectifier
ann.add(tf.keras.layers.Dense(units = 30, input_shape=(10,), activation = 'relu'))


#----------------------------------------------------------------------------------
# Adding "fully connected" SECOND layer to the Sequential AMM by calling Dense class
#----------------------------------------------------------------------------------
# Number of Units = 6 and Activation Function = Rectifier
ann.add(tf.keras.layers.Dense(units = 20, activation = 'relu'))

ann.add(tf.keras.layers.Dense(units = 10, activation = 'sigmoid'))
#----------------------------------------------------------------------------------
# Adding "fully connected" OUTPUT layer to the Sequential ANN by calling Dense class
#----------------------------------------------------------------------------------
# Number of Units = 1 and Activation Function = Sigmoid
ann.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# %%
#----------------------- Training the model -----------------------#
# Compiling the ANN
# Type of Optimizer = Adam Optimizer, Loss Function =  crossentropy for binary dependent variable, and Optimization is done w.r.t. accuracy
ann.compile(optimizer = 'adam', loss="binary_crossentropy",metrics=["accuracy"])

# Training the ANN model on training set  (fit method always the same)
# batch_size = 32, the default value, number of epochs  = 100
ann.fit(X_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 250/250 [==============================] - 2s 3ms/step - loss: 0.4908 - accuracy: 0.7960
# Epoch 2/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4168 - accuracy: 0.8234
# Epoch 3/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3897 - accuracy: 0.8411
# Epoch 4/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3697 - accuracy: 0.8497
# Epoch 5/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3572 - accuracy: 0.8528
# Epoch 6/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3497 - accuracy: 0.8571
# Epoch 7/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3448 - accuracy: 0.8595
# Epoch 8/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3408 - accuracy: 0.8590
# Epoch 9/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3386 - accuracy: 0.8619
# Epoch 10/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3362 - accuracy: 0.8626
# Epoch 11/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3343 - accuracy: 0.8622
# Epoch 12/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3327 - accuracy: 0.8641
# Epoch 13/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3309 - accuracy: 0.8619
# Epoch 14/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3282 - accuracy: 0.8666
# Epoch 15/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3272 - accuracy: 0.8664
# Epoch 16/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3266 - accuracy: 0.8680
# Epoch 17/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3255 - accuracy: 0.8668
# Epoch 18/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3248 - accuracy: 0.8662
# Epoch 19/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3241 - accuracy: 0.8668
# Epoch 20/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3217 - accuracy: 0.8685
# Epoch 21/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3218 - accuracy: 0.8696
# Epoch 22/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3210 - accuracy: 0.8683
# Epoch 23/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3199 - accuracy: 0.8685
# Epoch 24/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3186 - accuracy: 0.8689
# Epoch 25/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3182 - accuracy: 0.8723
# Epoch 26/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3169 - accuracy: 0.8712
# Epoch 27/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3157 - accuracy: 0.8708
# Epoch 28/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3150 - accuracy: 0.8711
# Epoch 29/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3141 - accuracy: 0.8712
# Epoch 30/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3156 - accuracy: 0.8717
# Epoch 31/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3139 - accuracy: 0.8705
# Epoch 32/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3129 - accuracy: 0.8726
# Epoch 33/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3122 - accuracy: 0.8721
# Epoch 34/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3116 - accuracy: 0.8735
# Epoch 35/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3106 - accuracy: 0.8752
# Epoch 36/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3107 - accuracy: 0.8749
# Epoch 37/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3094 - accuracy: 0.8746
# Epoch 38/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3095 - accuracy: 0.8754
# Epoch 39/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3091 - accuracy: 0.8748
# Epoch 40/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3086 - accuracy: 0.8748
# Epoch 41/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3079 - accuracy: 0.8750
# Epoch 42/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3076 - accuracy: 0.8763
# Epoch 43/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3075 - accuracy: 0.8748
# Epoch 44/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3060 - accuracy: 0.8756
# Epoch 45/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3057 - accuracy: 0.8775
# Epoch 46/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3056 - accuracy: 0.8754
# Epoch 47/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3031 - accuracy: 0.8750
# Epoch 48/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3044 - accuracy: 0.8763
# Epoch 49/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3042 - accuracy: 0.8739
# Epoch 50/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3034 - accuracy: 0.8777
# Epoch 51/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3024 - accuracy: 0.8785
# Epoch 52/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3025 - accuracy: 0.8769
# Epoch 53/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3015 - accuracy: 0.8790
# Epoch 54/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3024 - accuracy: 0.8777
# Epoch 55/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3008 - accuracy: 0.8775
# Epoch 56/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2998 - accuracy: 0.8776
# Epoch 57/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2999 - accuracy: 0.8784
# Epoch 58/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2999 - accuracy: 0.8770
# Epoch 59/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2995 - accuracy: 0.8800
# Epoch 60/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2998 - accuracy: 0.8769
# Epoch 61/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2982 - accuracy: 0.8785
# Epoch 62/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2983 - accuracy: 0.8792
# Epoch 63/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2961 - accuracy: 0.8790
# Epoch 64/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2962 - accuracy: 0.8811
# Epoch 65/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2970 - accuracy: 0.8813
# Epoch 66/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2965 - accuracy: 0.8791
# Epoch 67/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2959 - accuracy: 0.8784
# Epoch 68/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2958 - accuracy: 0.8796
# Epoch 69/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2946 - accuracy: 0.8820
# Epoch 70/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2946 - accuracy: 0.8792
# Epoch 71/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2956 - accuracy: 0.8800
# Epoch 72/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2947 - accuracy: 0.8784
# Epoch 73/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2933 - accuracy: 0.8809
# Epoch 74/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2932 - accuracy: 0.8824
# Epoch 75/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2933 - accuracy: 0.8806
# Epoch 76/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2928 - accuracy: 0.8811
# Epoch 77/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2935 - accuracy: 0.8827
# Epoch 78/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2926 - accuracy: 0.8804
# Epoch 79/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2923 - accuracy: 0.8814
# Epoch 80/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2907 - accuracy: 0.8829
# Epoch 81/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2907 - accuracy: 0.8788
# Epoch 82/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2907 - accuracy: 0.8830
# Epoch 83/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2917 - accuracy: 0.8792
# Epoch 84/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2908 - accuracy: 0.8805
# Epoch 85/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2894 - accuracy: 0.8838
# Epoch 86/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2891 - accuracy: 0.8820
# Epoch 87/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2888 - accuracy: 0.8835
# Epoch 88/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2897 - accuracy: 0.8816
# Epoch 89/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2903 - accuracy: 0.8814
# Epoch 90/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2883 - accuracy: 0.8824
# Epoch 91/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2879 - accuracy: 0.8802
# Epoch 92/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2874 - accuracy: 0.8834
# Epoch 93/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2880 - accuracy: 0.8817
# Epoch 94/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2874 - accuracy: 0.8827
# Epoch 95/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2866 - accuracy: 0.8831
# Epoch 96/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2856 - accuracy: 0.8825
# Epoch 97/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2856 - accuracy: 0.8844
# Epoch 98/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2858 - accuracy: 0.8845
# Epoch 99/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2862 - accuracy: 0.8808
# Epoch 100/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2858 - accuracy: 0.8820
# Epoch 101/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2835 - accuracy: 0.8839
# Epoch 102/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2848 - accuracy: 0.8838
# Epoch 103/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2854 - accuracy: 0.8842
# Epoch 104/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2838 - accuracy: 0.8841
# Epoch 105/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2827 - accuracy: 0.8848
# Epoch 106/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2827 - accuracy: 0.8850
# Epoch 107/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2833 - accuracy: 0.8851
# Epoch 108/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2829 - accuracy: 0.8841
# Epoch 109/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2832 - accuracy: 0.8842
# Epoch 110/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2845 - accuracy: 0.8831
# Epoch 111/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2819 - accuracy: 0.8852
# Epoch 112/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2821 - accuracy: 0.8850
# Epoch 113/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2809 - accuracy: 0.8861
# Epoch 114/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2797 - accuracy: 0.8860
# Epoch 115/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2801 - accuracy: 0.8850
# Epoch 116/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2796 - accuracy: 0.8857
# Epoch 117/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2804 - accuracy: 0.8860
# Epoch 118/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2797 - accuracy: 0.8839
# Epoch 119/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2793 - accuracy: 0.8859
# Epoch 120/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2799 - accuracy: 0.8839
# Epoch 121/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2789 - accuracy: 0.8869
# Epoch 122/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2785 - accuracy: 0.8876
# Epoch 123/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2775 - accuracy: 0.8856
# Epoch 124/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2799 - accuracy: 0.8860
# Epoch 125/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2773 - accuracy: 0.8875
# Epoch 126/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2772 - accuracy: 0.8876
# Epoch 127/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2776 - accuracy: 0.8864
# Epoch 128/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2774 - accuracy: 0.8860
# Epoch 129/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2772 - accuracy: 0.8878
# Epoch 130/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2771 - accuracy: 0.8891
# Epoch 131/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2774 - accuracy: 0.8851
# Epoch 132/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2760 - accuracy: 0.8866
# Epoch 133/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2749 - accuracy: 0.8859
# Epoch 134/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2753 - accuracy: 0.8863
# Epoch 135/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2750 - accuracy: 0.8879
# Epoch 136/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2755 - accuracy: 0.8873
# Epoch 137/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2740 - accuracy: 0.8892
# Epoch 138/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2739 - accuracy: 0.8878
# Epoch 139/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2756 - accuracy: 0.8876
# Epoch 140/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2749 - accuracy: 0.8864
# Epoch 141/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2741 - accuracy: 0.8906
# Epoch 142/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2736 - accuracy: 0.8879
# Epoch 143/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2722 - accuracy: 0.8895
# Epoch 144/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2738 - accuracy: 0.8891
# Epoch 145/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2722 - accuracy: 0.8891
# Epoch 146/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2739 - accuracy: 0.8880
# Epoch 147/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2725 - accuracy: 0.8875
# Epoch 148/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2727 - accuracy: 0.8886
# Epoch 149/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2722 - accuracy: 0.8879
# Epoch 150/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2699 - accuracy: 0.8886
# Epoch 151/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2723 - accuracy: 0.8881
# Epoch 152/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2712 - accuracy: 0.8881
# Epoch 153/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2694 - accuracy: 0.8892
# Epoch 154/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2706 - accuracy: 0.8910
# Epoch 155/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2693 - accuracy: 0.8917
# Epoch 156/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2716 - accuracy: 0.8898
# Epoch 157/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2694 - accuracy: 0.8891
# Epoch 158/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2702 - accuracy: 0.8907
# Epoch 159/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2697 - accuracy: 0.8901
# Epoch 160/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2695 - accuracy: 0.8916
# Epoch 161/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2679 - accuracy: 0.8890
# Epoch 162/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2677 - accuracy: 0.8920
# Epoch 163/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2704 - accuracy: 0.8913
# Epoch 164/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2680 - accuracy: 0.8904
# Epoch 165/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2678 - accuracy: 0.8913
# Epoch 166/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2670 - accuracy: 0.8901
# Epoch 167/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2657 - accuracy: 0.8913
# Epoch 168/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2664 - accuracy: 0.8879
# Epoch 169/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2672 - accuracy: 0.8905
# Epoch 170/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2660 - accuracy: 0.8920
# Epoch 171/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2661 - accuracy: 0.8905
# Epoch 172/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2660 - accuracy: 0.8923
# Epoch 173/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2659 - accuracy: 0.8916
# Epoch 174/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2674 - accuracy: 0.8899
# Epoch 175/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2659 - accuracy: 0.8917
# Epoch 176/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2642 - accuracy: 0.8932
# Epoch 177/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2650 - accuracy: 0.8919
# Epoch 178/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2654 - accuracy: 0.8917
# Epoch 179/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2665 - accuracy: 0.8921
# Epoch 180/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2642 - accuracy: 0.8916
# Epoch 181/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2656 - accuracy: 0.8932
# Epoch 182/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2625 - accuracy: 0.8905
# Epoch 183/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2632 - accuracy: 0.8906
# Epoch 184/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2631 - accuracy: 0.8956
# Epoch 185/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2639 - accuracy: 0.8913
# Epoch 186/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2628 - accuracy: 0.8938
# Epoch 187/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2622 - accuracy: 0.8947
# Epoch 188/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2621 - accuracy: 0.8932
# Epoch 189/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2619 - accuracy: 0.8941
# Epoch 190/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2620 - accuracy: 0.8939
# Epoch 191/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2624 - accuracy: 0.8907
# Epoch 192/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2619 - accuracy: 0.8913
# Epoch 193/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2616 - accuracy: 0.8924
# Epoch 194/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2617 - accuracy: 0.8940
# Epoch 195/200
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2607 - accuracy: 0.8960
# Epoch 196/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2613 - accuracy: 0.8909
# Epoch 197/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2614 - accuracy: 0.8925
# Epoch 198/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2608 - accuracy: 0.8925
# Epoch 199/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2611 - accuracy: 0.8931
# Epoch 200/200
# 250/250 [==============================] - 1s 2ms/step - loss: 0.2589 - accuracy: 0.8950

# %%
#Confusion Matrix
cf = confusion_matrix(y_test, y_pred)
print("Confusion Matrix", cf)
print("Accuracy Score", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix [[1499   96]
#  [ 197  208]]
# Accuracy Score 0.8535

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Calculate precision, recall, and F1 score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Print the results
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
# Out:
# Precision: 0.68
# Recall: 0.51
# F1 Score: 0.59

# %%
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:825, in Parallel.dispatch_one_batch(self, iterator)
#     824 try:
# --> 825     tasks = self._ready_batches.get(block=False)
#     826 except queue.Empty:
#     827     # slice the iterator n_jobs * batchsize items at a time. If the
#     828     # slice returns less than that, then the current batchsize puts
#    (...)
#     831     # accordingly to distribute evenly the last items between all
#     832     # workers.
#
# File ~\anaconda3\lib\queue.py:168, in Queue.get(self, block, timeout)
#     167     if not self._qsize():
# --> 168         raise Empty
#     169 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[192], line 16
#      13 kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)
#      15 # Perform 10-fold cross-validation
# ---> 16 fold_accuracies = cross_val_score(ann, X, y, cv=kf, scoring='accuracy')
#      18 # Print the accuracy for each fold
#      19 for fold, accuracy in enumerate(fold_accuracies, 1):
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1048, in Parallel.__call__(self, iterable)
#    1039 try:
#    1040     # Only set self._iterating to True if at least a batch
#    1041     # was dispatched. In particular this covers the edge
#    (...)
#    1045     # was very quick and its callback already dispatched all the
#    1046     # remaining jobs.
#    1047     self._iterating = False
# -> 1048     if self.dispatch_one_batch(iterator):
#    1049         self._iterating = self._original_iterator is not None
#    1051     while self.dispatch_one_batch(iterator):
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:836, in Parallel.dispatch_one_batch(self, iterator)
#     833 n_jobs = self._cached_effective_n_jobs
#     834 big_batch_size = batch_size * n_jobs
# --> 836 islice = list(itertools.islice(iterator, big_batch_size))
#     837 if len(islice) == 0:
#     838     return False
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py:59, in <genexpr>(.0)
#      54 # Capture the thread-local scikit-learn configuration at the time
#      55 # Parallel.__call__ is issued since the tasks can be dispatched
#      56 # in a different thread depending on the backend and on the value of
#      57 # pre_dispatch and n_jobs.
#      58 config = get_config()
# ---> 59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
#      63 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:268, in <genexpr>(.0)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     266 results = parallel(
#     267     delayed(_fit_and_score)(
# --> 268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:79, in clone(estimator, safe)
#      73             raise TypeError(
#      74                 "Cannot clone object. "
#      75                 + "You should provide an instance of "
#      76                 + "scikit-learn estimator instead of a class."
#      77             )
#      78         else:
# ---> 79             raise TypeError(
#      80                 "Cannot clone object '%s' (type %s): "
#      81                 "it does not seem to be a scikit-learn "
#      82                 "estimator as it does not implement a "
#      83                 "'get_params' method." % (repr(estimator), type(estimator))
#      84             )
#      86 klass = estimator.__class__
#      87 new_object_params = estimator.get_params(deep=False)
#
# TypeError: Cannot clone object '<keras.src.engine.sequential.Sequential object at 0x000002183D045F60>' (type <class 'keras.src.engine.sequential.Sequential'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
